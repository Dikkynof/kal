# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/kal
# Out:
# /content/drive/MyDrive/kal

# %%
# !pip uninstall jupyter-book -y
# Out:
# Found existing installation: jupyter-book 2.1.2
# Uninstalling jupyter-book-2.1.2:
#   Successfully uninstalled jupyter-book-2.1.2

# %%
# !pip install jupyter-book==0.15.1
# Out:
# ...
#   Using cached jupyter_book-0.15.1-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached jupyter_book-0.15.1-py3-none-any.whl (43 kB)
# ...

# %%
# !jupyter-book --version
# Out:
# Jupyter Book      : 0.15.1
# External ToC      : 0.3.1
# MyST-Parser       : 0.18.1
# MyST-NB           : 0.17.2
# Sphinx Book Theme : 1.0.1
# Jupyter-Cache     : 0.6.1
# NbClient          : 0.7.4

# %%
# !which jupyter-book
# Out:
# /usr/local/bin/jupyter-book

# %%
# !jupyter-book create materi/
# Out:
# ...
#
# Your book template can be found at
#
#     materi/
#
# ...

# %%
# %cd /content/drive/MyDrive/kal/materi
# Out:
# /content/drive/MyDrive/kal/materi

# %%
# !jupyter-book build .
#sekali
# Out:
# Running Jupyter-Book v0.15.1
# Source Folder: /content/drive/MyDrive/kal/materi
# Config Path: /content/drive/MyDrive/kal/materi/_config.yml
# Output Path: /content/drive/MyDrive/kal/materi/_build/html
# [sphinxcontrib-bibtex] Beware that docutils versions 0.18 and 0.19 (you are running 0.18.1) are known to generate invalid html for citations. If this issue affects you, please use docutils<0.18 (or >=0.20 once released) instead. For more details, see https://sourceforge.net/p/docutils/patches/195/
# Running Sphinx v5.0.2
# making output directory... done
# [etoc] Changing master_doc to 'intro'
# checking bibtex cache... out of date
# parsing bibtex file /content/drive/MyDrive/kal/materi/references.bib... parsed 5 entries
# ...

# %%
# %cd /content/drive/MyDrive/kal/materi/_build/html
# Out:
# /content/drive/MyDrive/kal/materi/_build/html

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !ls
# Out:
# genindex.html  markdown-notebooks.html	Sistem_Persamaan_Linier.html
# _images        notebooks.html		_sources
# index.html     objects.inv		_sphinx_design_static
# intro.html     search.html		_static
# markdown.html  searchindex.js		Tugas2_persamaan_linier.html

# %%
# %cd /content/drive/MyDrive/kal/
# Out:
# /content/drive/MyDrive/kal

# %%
# !rm -rf .git

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/kal/.git/
